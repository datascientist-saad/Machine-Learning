# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import adam_v2
from keras import regularizers

# %% [markdown]
# Read labels for dogs

# %%
labels_all = pd.read_csv("dog_dataset\dogbreedidfromcomp\labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# Visualize the number of each breed

# %%
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %% [markdown]
# Selecting first 3 breeds

# %%
CLASS_NAMES = ['scottish_deerhound', 'maltese_dog', 'bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id                 breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec           maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 4    118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %% [markdown]
# One hot encoding

# %%
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes=CLASS_NAMES)

# Reading and converting image to numy array and normalizing dataset

for i in tqdm(range(len(labels))):
    img = image.load_img('dog_dataset/dogbreedidfromcomp/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x/255.0
    
print('\nTrain Images shape: ', X_data.shape, ' size: {:,}'.format(X_data.size))
print('One hot encoded output shape: ', Y_data.shape, ' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 357/357 [00:01<00:00, 207.44it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One hot encoded output shape:  (357, 3)  size: 1,071

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation='relu', kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation='relu',kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation='relu', kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu', kernel_regularizer='l2'))
model.add(Dense(64, activation = 'relu', kernel_regularizer='l2'))
model.add(Dense(len(CLASS_NAMES), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# train - test split

# %%
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)

X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %% [markdown]
# Training model

# %%
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 14s 8s/step - loss: 1.0468 - accuracy: 0.9766 - val_loss: 1.8174 - val_accuracy: 0.7692
# Epoch 2/100
# 2/2 [==============================] - 15s 8s/step - loss: 1.0097 - accuracy: 0.9805 - val_loss: 1.8646 - val_accuracy: 0.7385
# Epoch 3/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.9880 - accuracy: 0.9883 - val_loss: 1.9333 - val_accuracy: 0.6769
# Epoch 4/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.9819 - accuracy: 0.9844 - val_loss: 1.9558 - val_accuracy: 0.7231
# Epoch 5/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.9507 - accuracy: 0.9961 - val_loss: 2.1494 - val_accuracy: 0.6615
# Epoch 6/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.9483 - accuracy: 0.9883 - val_loss: 1.9394 - val_accuracy: 0.7692
# Epoch 7/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.9309 - accuracy: 0.9922 - val_loss: 2.1361 - val_accuracy: 0.6923
# Epoch 8/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.9314 - accuracy: 0.9922 - val_loss: 1.9657 - val_accuracy: 0.7385
# Epoch 9/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.9135 - accuracy: 0.9922 - val_loss: 2.0950 - val_accuracy: 0.7077
# Epoch 10/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.8978 - accuracy: 0.9922 - val_loss: 2.0331 - val_accuracy: 0.7077
# Epoch 11/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.8875 - accuracy: 0.9961 - val_loss: 2.1623 - val_accuracy: 0.6462
# Epoch 12/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.8790 - accuracy: 0.9961 - val_loss: 2.1347 - val_accuracy: 0.7385
# Epoch 13/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.8714 - accuracy: 0.9961 - val_loss: 2.1524 - val_accuracy: 0.6769
# Epoch 14/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.8730 - accuracy: 0.9883 - val_loss: 1.9832 - val_accuracy: 0.7692
# Epoch 15/100
# 2/2 [==============================] - 17s 10s/step - loss: 0.8540 - accuracy: 1.0000 - val_loss: 2.3069 - val_accuracy: 0.6923
# Epoch 16/100
# 2/2 [==============================] - 16s 9s/step - loss: 0.8496 - accuracy: 0.9961 - val_loss: 2.0628 - val_accuracy: 0.7538
# Epoch 17/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.8436 - accuracy: 1.0000 - val_loss: 2.5638 - val_accuracy: 0.6615
# Epoch 18/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.8546 - accuracy: 0.9844 - val_loss: 2.2244 - val_accuracy: 0.6923
# Epoch 19/100
# 2/2 [==============================] - 15s 8s/step - loss: 0.8580 - accuracy: 0.9922 - val_loss: 2.8134 - val_accuracy: 0.6615
# Epoch 20/100
# 2/2 [==============================] - 14s 8s/step - loss: 0.9548 - accuracy: 0.9180 - val_loss: 3.2468 - val_accuracy: 0.6154
# Epoch 21/100
# 2/2 [==============================] - 14s 7s/step - loss: 1.0574 - accuracy: 0.8789 - val_loss: 1.9777 - val_accuracy: 0.7385
# Epoch 22/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.8696 - accuracy: 0.9766 - val_loss: 2.1091 - val_accuracy: 0.7077
# Epoch 23/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.8238 - accuracy: 0.9961 - val_loss: 1.9647 - val_accuracy: 0.6923
# Epoch 24/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.8483 - accuracy: 0.9844 - val_loss: 2.1929 - val_accuracy: 0.6769
# Epoch 25/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.8595 - accuracy: 0.9766 - val_loss: 1.9541 - val_accuracy: 0.7077
# Epoch 26/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.8076 - accuracy: 0.9961 - val_loss: 1.8937 - val_accuracy: 0.6769
# Epoch 27/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.8236 - accuracy: 0.9922 - val_loss: 2.1528 - val_accuracy: 0.6769
# Epoch 28/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.8261 - accuracy: 0.9883 - val_loss: 1.9820 - val_accuracy: 0.6923
# Epoch 29/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.7876 - accuracy: 1.0000 - val_loss: 1.7754 - val_accuracy: 0.7077
# Epoch 30/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7983 - accuracy: 1.0000 - val_loss: 1.8188 - val_accuracy: 0.6923
# Epoch 31/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7859 - accuracy: 0.9922 - val_loss: 2.0970 - val_accuracy: 0.6615
# Epoch 32/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7750 - accuracy: 0.9961 - val_loss: 1.9908 - val_accuracy: 0.7231
# Epoch 33/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7744 - accuracy: 0.9961 - val_loss: 1.9549 - val_accuracy: 0.6923
# Epoch 34/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7557 - accuracy: 1.0000 - val_loss: 2.1746 - val_accuracy: 0.6615
# Epoch 35/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7538 - accuracy: 1.0000 - val_loss: 2.2401 - val_accuracy: 0.6615
# Epoch 36/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.7454 - accuracy: 1.0000 - val_loss: 2.0543 - val_accuracy: 0.7077
# Epoch 37/100
# 2/2 [==============================] - 12s 7s/step - loss: 0.7388 - accuracy: 1.0000 - val_loss: 1.9349 - val_accuracy: 0.7231
# Epoch 38/100
# 2/2 [==============================] - 14s 8s/step - loss: 0.7334 - accuracy: 1.0000 - val_loss: 1.9407 - val_accuracy: 0.7077
# Epoch 39/100
# 2/2 [==============================] - 15s 7s/step - loss: 0.7279 - accuracy: 1.0000 - val_loss: 2.0175 - val_accuracy: 0.7077
# Epoch 40/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.7212 - accuracy: 1.0000 - val_loss: 2.1396 - val_accuracy: 0.7231
# Epoch 41/100
# 2/2 [==============================] - 15s 7s/step - loss: 0.7167 - accuracy: 1.0000 - val_loss: 2.1630 - val_accuracy: 0.7231
# Epoch 42/100
# 2/2 [==============================] - 14s 8s/step - loss: 0.7117 - accuracy: 1.0000 - val_loss: 2.0912 - val_accuracy: 0.7077
# Epoch 43/100
# 2/2 [==============================] - 15s 8s/step - loss: 0.7061 - accuracy: 1.0000 - val_loss: 2.0310 - val_accuracy: 0.7385
# Epoch 44/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.7012 - accuracy: 1.0000 - val_loss: 2.0195 - val_accuracy: 0.7231
# Epoch 45/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6965 - accuracy: 1.0000 - val_loss: 2.0391 - val_accuracy: 0.6769
# Epoch 46/100
# 2/2 [==============================] - 12s 7s/step - loss: 0.6911 - accuracy: 1.0000 - val_loss: 2.0782 - val_accuracy: 0.7077
# Epoch 47/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6863 - accuracy: 1.0000 - val_loss: 2.1045 - val_accuracy: 0.7077
# Epoch 48/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.6817 - accuracy: 1.0000 - val_loss: 2.0625 - val_accuracy: 0.7077
# Epoch 49/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6766 - accuracy: 1.0000 - val_loss: 2.0209 - val_accuracy: 0.6923
# Epoch 50/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6720 - accuracy: 1.0000 - val_loss: 2.0143 - val_accuracy: 0.6923
# Epoch 51/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6675 - accuracy: 1.0000 - val_loss: 2.0288 - val_accuracy: 0.7077
# Epoch 52/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6628 - accuracy: 1.0000 - val_loss: 2.0486 - val_accuracy: 0.7077
# Epoch 53/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.6585 - accuracy: 1.0000 - val_loss: 2.0583 - val_accuracy: 0.6923
# Epoch 54/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6542 - accuracy: 1.0000 - val_loss: 2.0503 - val_accuracy: 0.7077
# Epoch 55/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.6497 - accuracy: 1.0000 - val_loss: 2.0134 - val_accuracy: 0.7077
# Epoch 56/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6456 - accuracy: 1.0000 - val_loss: 1.9964 - val_accuracy: 0.7077
# Epoch 57/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.6413 - accuracy: 1.0000 - val_loss: 2.0030 - val_accuracy: 0.6923
# Epoch 58/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6373 - accuracy: 1.0000 - val_loss: 2.0077 - val_accuracy: 0.6923
# Epoch 59/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6331 - accuracy: 1.0000 - val_loss: 1.9986 - val_accuracy: 0.6923
# Epoch 60/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.6291 - accuracy: 1.0000 - val_loss: 1.9821 - val_accuracy: 0.6923
# Epoch 61/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.6252 - accuracy: 1.0000 - val_loss: 1.9768 - val_accuracy: 0.7077
# Epoch 62/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.6213 - accuracy: 1.0000 - val_loss: 1.9788 - val_accuracy: 0.7077
# Epoch 63/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6174 - accuracy: 1.0000 - val_loss: 1.9822 - val_accuracy: 0.6923
# Epoch 64/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6137 - accuracy: 1.0000 - val_loss: 1.9549 - val_accuracy: 0.6923
# Epoch 65/100
# 2/2 [==============================] - 12s 7s/step - loss: 0.6098 - accuracy: 1.0000 - val_loss: 1.9339 - val_accuracy: 0.7077
# Epoch 66/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6062 - accuracy: 1.0000 - val_loss: 1.9432 - val_accuracy: 0.7077
# Epoch 67/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.6024 - accuracy: 1.0000 - val_loss: 1.9431 - val_accuracy: 0.6923
# Epoch 68/100
# 2/2 [==============================] - 14s 8s/step - loss: 0.5988 - accuracy: 1.0000 - val_loss: 1.9329 - val_accuracy: 0.7077
# Epoch 69/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5951 - accuracy: 1.0000 - val_loss: 1.9259 - val_accuracy: 0.7077
# Epoch 70/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5916 - accuracy: 1.0000 - val_loss: 1.9105 - val_accuracy: 0.7077
# Epoch 71/100
# 2/2 [==============================] - 12s 7s/step - loss: 0.5880 - accuracy: 1.0000 - val_loss: 1.9210 - val_accuracy: 0.7077
# Epoch 72/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5845 - accuracy: 1.0000 - val_loss: 1.9272 - val_accuracy: 0.7077
# Epoch 73/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.5812 - accuracy: 1.0000 - val_loss: 1.9131 - val_accuracy: 0.7077
# Epoch 74/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.5777 - accuracy: 1.0000 - val_loss: 1.9001 - val_accuracy: 0.7077
# Epoch 75/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5743 - accuracy: 1.0000 - val_loss: 1.9034 - val_accuracy: 0.7077
# Epoch 76/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5710 - accuracy: 1.0000 - val_loss: 1.9037 - val_accuracy: 0.7077
# Epoch 77/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.5676 - accuracy: 1.0000 - val_loss: 1.9055 - val_accuracy: 0.7077
# Epoch 78/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5643 - accuracy: 1.0000 - val_loss: 1.8942 - val_accuracy: 0.7077
# Epoch 79/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5610 - accuracy: 1.0000 - val_loss: 1.8991 - val_accuracy: 0.7077
# Epoch 80/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5576 - accuracy: 1.0000 - val_loss: 1.8797 - val_accuracy: 0.7077
# Epoch 81/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.5545 - accuracy: 1.0000 - val_loss: 1.8805 - val_accuracy: 0.7077
# Epoch 82/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5512 - accuracy: 1.0000 - val_loss: 1.8758 - val_accuracy: 0.7077
# Epoch 83/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5481 - accuracy: 1.0000 - val_loss: 1.8816 - val_accuracy: 0.7077
# Epoch 84/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5451 - accuracy: 1.0000 - val_loss: 1.8725 - val_accuracy: 0.7077
# Epoch 85/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.5418 - accuracy: 1.0000 - val_loss: 1.8902 - val_accuracy: 0.7077
# Epoch 86/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5390 - accuracy: 1.0000 - val_loss: 1.8801 - val_accuracy: 0.7077
# Epoch 87/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5356 - accuracy: 1.0000 - val_loss: 1.8533 - val_accuracy: 0.7077
# Epoch 88/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5327 - accuracy: 1.0000 - val_loss: 1.9000 - val_accuracy: 0.7077
# Epoch 89/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5297 - accuracy: 1.0000 - val_loss: 1.8878 - val_accuracy: 0.6923
# Epoch 90/100
# 2/2 [==============================] - 14s 7s/step - loss: 0.5266 - accuracy: 1.0000 - val_loss: 1.8429 - val_accuracy: 0.7077
# Epoch 91/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5238 - accuracy: 1.0000 - val_loss: 1.8742 - val_accuracy: 0.7077
# Epoch 92/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5207 - accuracy: 1.0000 - val_loss: 1.8525 - val_accuracy: 0.7077
# Epoch 93/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5177 - accuracy: 1.0000 - val_loss: 1.8522 - val_accuracy: 0.7077
# Epoch 94/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5152 - accuracy: 1.0000 - val_loss: 1.8684 - val_accuracy: 0.6923
# Epoch 95/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5123 - accuracy: 1.0000 - val_loss: 1.8533 - val_accuracy: 0.6923
# Epoch 96/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.5094 - accuracy: 1.0000 - val_loss: 1.8196 - val_accuracy: 0.7385
# Epoch 97/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5070 - accuracy: 1.0000 - val_loss: 1.8849 - val_accuracy: 0.6923
# Epoch 98/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5040 - accuracy: 1.0000 - val_loss: 1.8144 - val_accuracy: 0.7385
# Epoch 99/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.5014 - accuracy: 1.0000 - val_loss: 1.8559 - val_accuracy: 0.7077
# Epoch 100/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.4981 - accuracy: 1.0000 - val_loss: 1.8732 - val_accuracy: 0.6769

# %% [markdown]
# Plotting training history

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.xlabel('Accuracy')
plt.ylabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# predict

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 38ms/step - loss: 1.5462 - accuracy: 0.8333
# Accuracy over the test set:
#  83.33 %

# %%
plt.imshow(X_test[1, :, :, :])
plt.show()

print("Originally: ", labels['breed'][np.argmax(Y_test[1])])
print("Predicted: ", labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally:  scottish_deerhound
# Predicted:  scottish_deerhound
